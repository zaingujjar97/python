# %%
class car :
    def __init__ (self, name, brand, engine, color, number):
        self.name = name
        self.brand = brand
        self.engine = engine
        self.color = color 
        self.number = number

car1 = car ( "m4", "mercendies", "v9:, "black", "pk4423" )
print(car1.name)
# Out:
#   Cell In[10], line 9
#     car1 = car ( "m4", "mercendies", "v9:, "black", "pk4423" )
#                                                            ^
# SyntaxError: unterminated string literal (detected at line 9)
