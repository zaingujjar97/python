# %% [markdown]
# # **01 – Environment Setup**
#
# **Text Explanation:**
#
# Is class mein aap seekhte hain ke Python ko kaise install karna hai, virtual environment kaise create karte hain, aur IDE (jaise Visual Studio Code) ko configure karte hain. Ye steps ensure karte hain ke aapka development environment sahi tarah se set up ho.
#
# **Explanation:**
#
# python -m venv myenv command ek isolated environment banata hai jisme aap dependencies ko manage kar sakte hain.
# Environment activate karne ke baad, aap apne IDE se code likh sakte hain.
# python --version se aap verify karte hain ke sahi version installed hai.
#
# **Example :**

# %%
# Terminal commands (commands ko terminal mein run karein)

# Python ke sath ek virtual environment banana:
python -m venv myenv

# Windows par virtual environment activate karna:
myenv\Scripts\activate

# Mac/Linux par:
source myenv/bin/activate

# Python version check karne ke liye:
python --version

# %% [markdown]
# # **02 – Hello World**
#
# **Text Explanation:**
#
# Ye pehla program hai jo aap likhenge. Iska maqsad basic syntax aur program execution ka process samjhana hai. "Hello World" ke zariye aap dekhte hain ke kaise Python script likhi aur run hoti hai.
#
# **Example :**

# %%
# Yeh ek basic example hai jo Python ke structure ko dikhata hai.
print("Python is a high-level, interpreted programming language.")
# Out:
# Hello, World!

# %% [markdown]
# # **03 – Python Data Types & Arithmetic operations**
# **Text Explanation:**
#
# Yahan aap variables, data types (integer, float, string, boolean) aur basic operators (addition, subtraction, etc.) se introduce hote hain.
#
#
# Python Data Types - Simple & Easy Explanation
#
# 1. **Integer (int) -**
#
#    age = 25
#    price = -100
#
# 2. **Float (float) -**
#
#    pi = 3.14
#    weight = 55.5
#
# 3. **String (str) -**
#
#    name = "Ali"
#    city = 'Karachi'
#
# 4. **Boolean (bool) -**
#
#    is_raining = True
#    is_sunny = False
#
# 5. **List (list) -**
#
#    numbers = [1, 2, 3, 4, 5]
#    fruits = ["apple", "banana", "cherry"]
#
# 6. **Tuple (tuple) -**
#    colors = ("red", "green", "blue")
#    dimensions = (1920, 1080)
#
# 7. **Dictionary (dict) -**
#
#    student = {"name": "Ali", "age": 20, "city": "Lahore"}
#
# 8. **Set (set) - **
#
#    unique_numbers = {1, 2, 3, 4, 5}
#
# **Explanation: **
#
# Har variable ko alag data type assign kiya gaya hai.
# Arithmetic operations se numbers pe calculations ho rahi hain.
# String concatenation se multiple strings ko joda gaya hai.
# print() function se output console par display hota hai.
#
# **Example :**

# %%
# Variables aur data types
age = 25              # Integer
price = 99.99         # Float
name = "Usman Ashraf" # String
is_student = True     # Boolean

# Arithmetic operations
total = age + 5      # Addition
discounted_price = price - 10  # Subtraction

# String concatenation
greeting = "Hello, " + name + "!"

print("Age:", age)
print("Price:", price)
print("Discounted Price:", discounted_price)
print(greeting)
# Out:
# Age: 25
# Price: 99.99
# Discounted Price: 89.99
# Hello, Usman Ashraf!

# %% [markdown]
# # **04 – Interactive Exercises**
#
# **Text Explanation:**
#
# Is session mein interactive exercises ke through aap concepts ko practically apply karte hain. Aap input lena, simple calculations karna aur user se interaction seekhte hain.
#
# **Explanation:**
#
# input() function user se data leta hai.
# int() conversion se string ko number mein tabdeel kia jata hai.
# f-string (formatted string) se output ko readable format mein display kia jata hai.
#
# **Example :**

# %%
# User se input lekar unka naam aur umar display karna
name = input("Apna naam daalein: ")
age_input = input("Apni umar daalein: ")

# String input ko integer mein convert karna:
age = int(age_input)

print(f"Hello {name}, aapki umar {age} saal hai.")

# %% [markdown]
# # **05 – if else**
#
# **Text Explanation:**
#
# If-Else ek conditional statement hai jo decision making mein use hota hai. Iska istemal karke hum check karte hain ke koi condition true hai ya false, aur uske mutabiq code ka specific block execute karte hain.
#
# **Example :**

# %%
age = int(input("Please enter your age "))
weight = int(input(" Please enter your weight "))


if ( age <= 10 and weight <= 20) :
  print(" You are children ")
elif (age <= 18 and age > 10 and weight <= 40 ):
  print (" You are teenager ")
elif (age <= 30 and age > 18 and weight <= 70 ):
 print(" You are man ")
elif ( age <= 80 and age >30 and weight <= 110):
  print("You are a senior man ")
else :
  print (" You are overaged ")

# %% [markdown]
# # **06 – Tuples & Dictionaries**
#
# **Text Explanation:**
#
# Is class mein aapko do important data structures introduce karaye jate hain:
#
#
#
# *   **Tuple:** Ek immutable (badalne na dene wala) sequence of items, jo aap ek dafa set karne ke baad change nahi kar sakte.
# *   **Dictionary:** Key-value pairs ka collection jisme keys se values ko access kiya jata hai.
#
#
#
# **Explanation:**
#
# Tuple ko parenthesis mein define kiya jata hai aur uski values change nahi hoti.
# Dictionary mein keys aur values ko curly braces {} ke andar define kiya jata hai, jahan keys se values access hoti hain.
#
# **Example :**

# %%
# Tuple example: immutable sequence
fruits = ("apple", "banana", "cherry")
print("Fruits tuple:", fruits)
print("Pehla fruit:", fruits[0])

# Dictionary example: key-value pairs
# Example 1
user = {
    "name" : "zain",
    "age" : " five ",
    "gender" : "male"
}

print (user["name"])

# Example 2
user1 : dict = {
    "name" : "hamza",
    "class" : 15,
    "roll_no" : "pkaaaa"
}

user2 : dict = {
    "name" : "usman",
    "class" : 19,
    "roll_no" : "pkaaabb"
}
user3 : dict = {
    "name" : "usman",
    "class" : 19,
    "roll_no" : "pkaaa77"
}

print(user2["name"])
print(user3["roll_no"])
print(user2)

# %% [markdown]
# # **07 –List index**
#
# List index se murad hai list ke andar har element ka specific position number. Python mein lists ordered collections hoti hain, jismein pehla element index 0 se shuru hota hai, phir 1, 2, aur aise hi aage.

# %%
#shopping list
shoping_list : list[str] = [ "juice","milk","fruit","water","bread" ]

print(shoping_list [4])
print(shoping_list[2])

# Find the Lenght of the list
print(len(shoping_list))

# List slicing
print(shoping_list[2:5])
print(shoping_list)

#remove in list
shoping_list.remove("milk")
print(shoping_list)

# insert in list
shoping_list.insert(2, "sugar")
print(shoping_list)

#pop in list
shoping_list.pop(4)
print(shoping_list)

# %% [markdown]
# # **08 – Functions**
#
# **Text Explanation:**
#
# Function ek reusable code block hai jo specific task perform karta hai. Is se code modular aur organized rehta hai. Functions code ko modular aur reusable banate hain.
# Yahan aap dekhenge ke function ke andar parameters, return statements, aur docstrings kaise use hote hain.
#
# **Explanation:**
#
# def factorial(n): se function define hota hai.
# Docstring function ke purpose ko bayan karta hai.
# For loop se factorial calculate hota hai aur result return hota hai.
#
# **Example :**

# %%
def factorial(n):
    """
    Is function ka maqsad n ka factorial calculate karna hai.
    Agar n 0 ho to factorial 1 return karta hai.
    """
    if n == 0:
        return 1
    else:
        result = 1
        # 1 se n tak multiplication
        for i in range(1, n + 1):
            result *= i
        return result

# Function ko call kar ke output dekhna
number = 5
print(f"{number} ka factorial hai:", factorial(number))

# %% [markdown]
# # **9 -- Comparison Operators**

# %%
# Comparison Operators:
#  == : Equal to
#  1= : Not equal to
#  >  : Greater than
#  <  : Less than
#  >= : Greater than or equal to
#  <= : Less than or equal to

# %% [markdown]
# ## **09 – Exceptions error handing**
# **Text Explanation:**
#
# Exceptions se murad hain runtime errors jo program ke execution ke dauran aa sakte hain. Exception handling se aap in errors ko manage kar sakte hain bina program ko crash kiye. Is se program crash hone se bach jata hai aur graceful error messages display hote hain.
#
#
# 1.   **try** **=** try block mein risky operation perform hota hai.
# 2.   **except =** except block error ko handle karta hai, jaise division by zero.
#
#
#
# **Explanation:**
#
# try block mein error aane ki possibility rakhi gayi hai.
# Specific exception (ZeroDivisionError) aur general exception handle kiye gaye hain.
# finally block har haal mein execute hota hai, chahe error aaye ya na aaye.
#
# **Example :**

# %%
try:
    num = int(input("Enter the number = "))
    result = num / 10
    print(f"YOUR RESULT: {result}")

except ZeroDivisionError:
    print("Error: You cannot divide by zero!")

except ValueError:
    print("Invalid input! Please enter a number.")

except Exception as e:
    print(f"Some unexpected error occurred:")

# %% [markdown]
# # **10 - For and while loop**
# **1. For Loop:**
# For loop ek sequence (jaise list, tuple, string) ya range ke elements par iterate karta hai. Har iteration mein aapko sequence ka next element milta hai.
#
# **2. While Loop:**
# While loop tab tak code execute karta hai jab tak given condition true hai.

# %%
# while loop
time = 10

while time >= 1 :
  print(f"start {time}...")
  time -= 1

print("GOOD NIGHT")

# for loop
number = [ 1, 2, 3, 4, 5, ]

for num in number:
  print( num**2 )

# %% [markdown]
# # **11 – Object-Oriented Programming (OOP)**
# **Text Explanation:**
#
# OOP mein aap classes aur objects ka istemal karte hain. Is se aap complex programs ko chhote, manageable parts mein divide kar sakte hain. Concepts mein inheritance aur method overriding shamil hain.
#
# **Explanation:**
#
# Animal class basic properties define karta hai.
# Dog aur Cat classes, Animal se inherit karke apna speak() method override karti hain.
# Objects create kar ke unke methods call kiye jate hain.
#
# **examples :**

# %%
# Class
class bmw:
  def __init__(car,name,model,color,engine):
    car.name = name
    car.model = model
    car.color = color
    car.engine = engine

  def __str__(car):
    return f"Name: {car.name}\nModel: {car.model}\nColor: {car.color}\nEngine: {car.engine}"


car1 = bmw ("odi", 2004, "black", "v8")
print(car1)

# %%
# Base class: Animal
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return "Koi khas sound nahi."

# Derived class: Dog, jo Animal se inherit karta hai
class Dog(Animal):
    def speak(self):
        return f"{self.name} bolta hai: Bark!"

# Derived class: Cat, jo Animal se inherit karta hai
class Cat(Animal):
    def speak(self):
        return f"{self.name} bolta hai: Meow!"

# Objects create karna
dog1 = Dog("Max")
cat1 = Cat("Mia")

print(dog1.speak())
print(cat1.speak())

# %% [markdown]
# # **12 – Version Control with Git**
#
# **Text Explanation:**
#
# Is session mein Git ka istemal sikhaya jata hai jo code ke versions ko track karne mein madad karta hai. Aapko basic Git commands aur workflow se introduce karwaya jata hai.
#
# **Explanation:**
#
# git init se naye repository banate hain.
# git add . se sabhi files stage hoti hain.
# git commit se changes record hote hain.
# Remote repository se collaboration aur backup possible hota hai.
#
# **Example :**

# %%
# Git repository initialize karna:
git init

# Files ko staging area mein add karna:
git add .

# Changes commit karna:
git commit -m "Initial commit with project structure"

# Remote repository (GitHub) set karna:
git remote add origin https://github.com/username/repository.git

# Code ko remote repository par push karna:
git push -u origin main

# %% [markdown]
# # **13 – Modules**
# **Text Explanation:**
#
# Is session mein code ko alag files (modules) mein organize karna sikhaya jata hai. Is se code reusability aur maintainability badh jati hai. Aap dekhte hain kaise ek module bana kar uske functions ko import karke use kiya jata hai.
#
# **Explanation:**
#
# mymodule.py mein functions define kiye gaye hain.
# main.py mein un functions ko import karke use kiya jata hai.
# Is tarah se aap apne code ko modular banate hain.
#
# **Explanation:**
#
# Module file: mymodule.py

# %%
# mymodule.py
def greet(name):
    """User ko greet karne ka function."""
    return f"Hello, {name}! Welcome to the Python course."

def add_numbers(a, b):
    """Do numbers ka sum return karta hai."""
    return a + b

# %% [markdown]
# Main file: **main.py**

# %%
# main.py
from mymodule import greet, add_numbers

user = input("Apna naam daalein: ")
print(greet(user))

num1 = float(input("Pehla number daalein: "))
num2 = float(input("Dosra number daalein: "))
print("Sum:", add_numbers(num1, num2))

# %% [markdown]
# # **14 – Final Projects**
#
# Text Explanation:
#
# Is final session mein aap apni seekhi hui tamam skills ko aik chhote project mein integrate karte hain. Ye project real-world application jaisa hota hai jisme user input, data processing, error handling aur modular design shamil hoti hai.
#
#
#  **Explanation:**
#
#
# *   Menu Driven Program: User ko menu options diye gaye hain.
# *   Functions: Har functionality (task add, view, remove) ko alag function mein define kiya gaya hai.
#
# *   Looping & Control Flow: While loop continuously menu display karta hai jab tak user exit nahi karta.
# *   Error Handling: User input ke errors ko handle karne ke liye try-except use hua hai.

# %%
# Ek simple To-Do List application
def display_menu():
    print("\n==== To-Do List Menu ====")
    print("1. Task add karein")
    print("2. Tasks dekhain")
    print("3. Task remove karein")
    print("4. Exit")

def add_task(tasks):
    task = input("Naya task likhain: ")
    tasks.append(task)
    print(f"Task '{task}' add ho gaya hai.")

def view_tasks(tasks):
    if not tasks:
        print("Abhi tak koi task nahi.")
    else:
        print("\nAapke tasks:")
        for index, task in enumerate(tasks, start=1):
            print(f"{index}. {task}")

def remove_task(tasks):
    view_tasks(tasks)
    try:
        task_num = int(input("Remove karne ke liye task number daalein: "))
        if 1 <= task_num <= len(tasks):
            removed = tasks.pop(task_num - 1)
            print(f"Task '{removed}' remove ho gaya hai.")
        else:
            print("Invalid task number!")
    except ValueError:
        print("Please ek valid number daalein.")

def main():
    tasks = []
    while True:
        display_menu()
        choice = input("Apni choice (1-4) daalein: ")
        if choice == '1':
            add_task(tasks)
        elif choice == '2':
            view_tasks(tasks)
        elif choice == '3':
            remove_task(tasks)
        elif choice == '4':
            print("Program exit ho raha hai. Shukriya!")
            break
        else:
            print("Invalid choice, dobara try karein.")

if __name__ == "__main__":
    main()
