# %%
a = int(input("Please enter a number between 1-10 = "))
def table(x):
    for i in range(1,11):
        print(x," * ",i,"= ",x*i)

match a:
    case 1:
        table(1)
    case 2:
        table(2)
    case 3:
        table(3)
    case 4:
        table(4)
    case 5:
        table(5)
    case 6:
        table(6)
    case 7:
        table(7)
    case 8:
        table(8)
    case 9:
        table(9)
    case 10:
        table(10)

# %%
# 6.. Countdown Timer

# %%
# 5.. Hangman

# %%
# 4.. Rock, paper, scissors

# %%
# 2.. Guess the Number Game Python Project (computer)
import random

def guess_game():
    com_number = random.randint(1,10)
    user_input = int(input("PLEASE GESS THE NUMBER BETWEEN 1 TO 10 = "))


    while user_input != com_number:

        if user_input < com_number :
                print("you gess low, try again")
        elif user_input > com_number:
              print("you gell is higher ,try again")
        else:
              print(f"congratuation you gess the correct number {com_number}")
        user_input = int(input("PLEASE GESS THE NUMBER BETWEEN 1 TO 10 = "))


guess_game()

# %%
# 2.. Guess the Number Game Python Project (computer)
import random

def guess_game():
    com_number = random.randint(1,10)
    user_input = int(input("PLEASE GESS THE NUMBER BETWEEN 1 TO 10"))
    

    while user_input != com_number:
        user_input = int(input("PLEASE GESS THE NUMBER BETWEEN 1 TO 10"))
        if user_input > com_number :
                print("you gess low, try again")
        elif user_input < com_number:
              print("you gell is higher ,try again")
        else:
              print(f"congratuation you gess the correct number {com_number}")
        user_input = int(input("PLEASE GESS THE NUMBER BETWEEN 1 TO 10"))


guess_game()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 20
#      16               print(f"congratuation you gess the correct number {com_number}")
#      17         user_input = int(input("PLEASE GESS THE NUMBER BETWEEN 1 TO 10"))
# ---> 20 guess_game()
#
# Cell In[5], line 6, in guess_game()
#       4 def guess_game():
#       5     com_number = random.randint(1,10)
# ----> 6     user_input = int(input("PLEASE GESS THE NUMBER BETWEEN 1 TO 10"))
#       9     while user_input != com_number:
#      10         user_input = int(input("PLEASE GESS THE NUMBER BETWEEN 1 TO 10"))
#
# ValueError: invalid literal for int() with base 10: 'c'

# %%
# 1.. Mad libs Python Project

name = "zain"
print(f"My name is {name}")

#------------------------------------------------------------------

adj = input("Adjective: ")
verb1 = input("Verb: ")
verb2 = input("Verb: ")
famous_person = input("Famous person: ")

madlib = f"Computer programming is so {adj}! It makes me so excited all the time because \
I love to {verb1}. Stay hydrated and {verb2} like you are {famous_person}!"

print(madlib)
# Out:
# My name is zain
# Computer programming is so eassy! It makes me so excited all the time because I love to online work. Stay hydrated and work like you are alone mask!
